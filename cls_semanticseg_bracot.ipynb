# %% [markdown]
# # Code for running classification and semantic segmentation on BRACOT dataset
#
# *Version for Google Colab*
#
# *Based on [this](https://github.com/esgario/lara2018/)*

# %% [markdown]
# ***Connect on drive (if your data is on GDrive)***

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ***Import some libs***

# %%
import sys
sys.path.insert(0, '/content/drive/My Drive/Colab Notebooks/esgario_utils')
from main import run

# %% [markdown]
# ***Define output folder and input image from previous framework stage***

# %%
output_folder = '/content/drive/MyDrive/outputs/instance_seg_result/'
input_img = '/content/drive/MyDrive/ic2-dataset/test/20190831_163222.jpg'

# %% [markdown]
# ***Run the semantic segmentation + classification stage***

# %%
run(background_image_path=input_img,
    out_image_path='output_framework.png',
    instances_folder_path=output_folder)
